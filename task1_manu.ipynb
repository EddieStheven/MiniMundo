# %% [markdown]
# Task 1:
#
# E - Extrair dados desse csv
# T - Tratar os dados - FIltrar linhas duplicadas, .env
# L - Carregar todos os dados em um banco SQL

# %%
import pandas as pd
from sqlalchemy import create_engine
from pathlib import Path

# %% [markdown]
# # Extract

# %%
df = pd.read_csv(
    "../csv/2007.csv"
)

# %%
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        2007      1           1          1   1232.0        1225   1341.0
# 1        2007      1           1          1   1918.0        1905   2043.0
# 2        2007      1           1          1   2206.0        2130   2334.0
# 3        2007      1           1          1   1230.0        1200   1356.0
# 4        2007      1           1          1    831.0         830    957.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7453210  2007     12          15          6   1558.0        1605   1749.0
# 7453211  2007     12          15          6   1902.0        1851   2110.0
# 7453212  2007     12          15          6   1024.0        1025   1750.0
# 7453213  2007     12          15          6   1353.0        1315   1658.0
# 7453214  2007     12          15          6   1824.0        1800   2001.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %% [markdown]
# # Transform

# %%
df.duplicated().sum()
# Out:
# np.int64(27)

# %%
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier            str
# FlightNum              int64
# TailNum                  str
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                   str
# Dest                     str
# Distance               int64
# TaxiIn                 int64
# TaxiOut                int64
# Cancelled              int64
# CancellationCode         str
# Diverted               int64
# CarrierDelay           int64
# WeatherDelay           int64
# NASDelay               int64
# SecurityDelay          int64
# LateAircraftDelay      int64
# dtype: object

# %% [markdown]
# # Load

# %%
engine = create_engine("postgresql+psycopg2://postgres:dados123456@localhost:5432/postgres")

df.to_sql("task1_manu", engine, if_exists="replace", index=False )
